# %% [markdown]
# <a href="https://colab.research.google.com/github/roop01/maths_for_machine_learning/blob/main/linear_algebra/02_linear_transformations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Linear Transformations**
#
# Linear transformation is a fundamental concept in mathematics. *A linear transformation is a function from one vector space to another that respects the underlying (linear) structure of each vector space.* It is a mapping between two vector spaces that preserves the operations of vector addition and scalar multiplication. A linear transformation is a function that takes a vector and transforms it into another vector in a way that is consistent with the structure of the vector space.
#
# A transformation T is said to be linear, if it satisfies the following properties for all the vectors u and v in the vector spaces and for any scalar a
#
#     1.   Additivity  : T(u + v) = T(u) + T(v)
#     2.   Homogeneity : T(a*u) = a*T(u)
#
#
# **Matrix Representation of Linear Transformations:**
#
# One of the most powerful aspects of linear transformations is their representation using matrices. Given a linear transformation T from a vector space with dimension n to a vector space with dimension m, there exists an m x n matrix A such that for any vector x in the original space, the transformation can be computed as:
#
# T(x) = A * x
#
# Here, the matrix A encapsulates all the information about the transformation, and matrix multiplication is used to apply the transformation to a vector.
#
# Consider a matrix A of dimension (m, n) and a column vector x of dimension n. If you multiply the vector x with matrix A, it results into a new column vector Ax of dimension m. This operation is an example of a transformation.
#
# Every matrix transformation is a linear transformation. These properties ensure that linear transformations are predictable and consistent, making them particularly useful in various applications across mathematics and science.

# %% [markdown]
# **Examples of Linear Transformations:**
#
# Common examples of linear transformations include scaling, rotations, and shearing in geometric contexts. In these cases, the transformation matrix can be used to change the size, position, or shape of geometric figures in a consistent manner.
#
#
# * Stretching
# * Reflection
# * Rotation
# * Projection
#
# Linear transformations play a central role in linear algebra and have far-reaching implications in both theoretical and applied mathematics. Their ability to preserve the structure of vector spaces while enabling a wide range of manipulations makes them indispensable tools in many areas of study.
#
# Linear transformations are widely used in various fields such as computer graphics, where they are essential for rendering 3D objects onto a 2D screen. They are also crucial in solving systems of linear equations, which is a fundamental problem in numerous scientific and engineering disciplines.

# %% [markdown]
# **Kernel and Image of Linear Transformation:**
#
# The **kernel** (or null space) of a linear transformation is the subset of the domain that is transformed into the zero vector. It is also known as the null space or nullspace. It is a measure of the vectors that lose their identity under the transformation.
#
# A vector v is in the kernel of a matrix A if and only if Av=0.
#
# The kernel is a subspace of the domain, which means it is closed with respect to taking linear combinations. The zero vector always belongs to the kernel.
#
# Example:  Let's suppose that the matrix A represents a rate of return on investments. The range are all the rates of return that are achievable. The null space are all the investments that can be made that wouldn't change the rate of return at all.
#
# The **image** (or range) of T, is the set of all vectors that can be obtained by applying T to vectors from the original space.
# The dimensions of the kernel and image provide important information about the transformation, such as its injectivity and surjectivity.

# %% [markdown]
# # **Stretching**
#
# The matrix A stretches the vector x up to c units when A is multiplied with x.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#    Vector A is stretched by 2 unit
#
#     X = [1 2]
#     A = [2 0
#          0 2]
#
#    AX = [2 4]

# %% [markdown]
# # **Reflection**
#
# Reflection is a transformation that deals with reflecting an object across a reference axis.
#
# Consider a triangle whose vertices are: A(-1, 1), B(-2, 2) and C(-3, 1). This triangle is then reflected along the x-axis to form an inverted image of itself as shown in the figure below:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The vertices of the given triangle are represented by matrix P as:
#
#     [-1 -2 -3
#       1 2 1]
#
# Reflection across x-axis is characterized by the following transformation matrix A:
#
#         [1 0
#          0 -1]
#
#     A.P =  [-1 -2 -3
#             -1 -2 -1]
#
# The resultant matrix (A.P) gives the vertices of the triangle reflected across x-axis.
#
# Reflection across y-axis is characterized by the following transformation matrix:
#
#     A = [-1 0
#           0 1]
#
#     A.P = [1 2 3
#           1 2 1]
#
# The resultant matrix (A.P) reflects the vertices of triangle across y-axis.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Reflection of (x,y):
#
#     Across X-axis: (x,-y)
#     Across Y-axis: (-x,y)
#     Across y=x axis: (y,x)
#     Across y=-x axis: (-y,-x)
#     Across Origin: (-x, -y)

# %% [markdown]
# # **Rotation**
#
# Rotation of an object by θ degrees is characterized by the following matrix:
#
#     [cosθ sinθ
#     -sinθ cosθ]
#
#     Where, θ represents the angle in a clockwise direction.
#
#
# Suppose the vertices of the triangle are represented as:
#
#     [-1 -2 -3
#     1 2 1]
#
# If you want to rotate this triangle by 90 degrees clockwise, putting the value of θ as 90, matrix A reduces to
#
#     A = [0 1
#         -1 0]
#
# Then, the rotated triangle is:
#
#     A.P = [1 2 1
#           1 2 3]
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Projection**
#
# Projection of an object along the x-axis is characterized by the following matrix:
#
#     A = [1 0
#          0 0]
#
#     P = [-1 -2 -3
#           1 2 1 ]
#
# along the x-axis is:
#
#     A.P = [-1 -2 -3
#             0 0 0]
#
# Projection along the y-axis is characterized by the following matrix:
#
#     A = [0 0
#          0 1]
#
#     P = [-1 -2 -3
#           1 2 1 ]
#
# along the y-axis is:
#
#     A.P = [0 0 0
#           1 2 1]
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Excercise 1.1**
#
# Q1. Consider a triangle whose vertices are given as columns of the following matrix P:
#
#     [-1 -2 -3
#       1 2 1]
#
# Reflection across the line x=y is defined by the following transformation matrix A:
#
#       [0 1
#        1 0]
# Find the vertices of the triangle P if it is reflected across the line x=y?
#
# Ans:
#
#     A.P =  [1 2 1
#             -1 -2 -3]
#
# vertices of the triangle P:
#
#     A(1,-1) B(2,-2) C(1,-3)

# %% [markdown]
# Q2: Consider a triangle whose vertices are given as columns of the following matrix P:
#
#     [-1 -2 -3
#       1 2 1]
#
# Reflection across origin is characterized by the following transformation matrix:
#
#
#       [-1 0
#        0 -1]
#
# Find the vertices of the triangle when it is reflected across the origin?
#
# A.P =
#
#     [1 2 3
#      -1 -2 -1]
#
# vertices of the triangle P:
#
# A(1,-1) B(2,-2) C(3,-1)

# %% [markdown]
# # **Linear Equations**
#
# Consider a scenario where you need to predict the price of a house given its area in square feet. The prediction can be made based on historical data of the houses sold in that region as given below:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Predicting the price of a house can be achieved by finding the relationship between Area and Price from the given data. The following is a scatter plot of Area and Price:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This plot indicates that there is a linear relationship between the variables Area and Price. And the linear relationship is represented by an expression as shown below:
#
# **Y = β0 + β1x1 + ϵ  ------- (1)**
#
# where,
#
# Y is the target variable ‘Price’
#
# x1 is the variable ‘Area’
#
# β0, β1 are coefficients
#
# ϵ is the random error

# %% [markdown]
# When there are more independent variables in the dataset, the target variable can be in general represented as:
#
# **Y = β0 + β1x1 +…+ βrxr + ϵ**
#
# Find the optimal values of the coefficients β0 and β1.

# %% [markdown]
# **Solving a System of Linear Equations**
#
# ![image.png](data:image/png;base64,...)
#
# System of Linear Equations can be represented in the form Ax = b as:
#
# ![image.png](data:image/png;base64,...)
#
# In general, the matrix A is of dimension (m, n), x is a column vector of dimension n and b is a column vector of dimension m. A is called the Coefficient matrix and the matrix [A b] is called the Augmented matrix.
#
# For a given coefficient matrix A of dimension (m, n), if m = n and A is a Full Rank matrix, then, there exists precisely one solution for the System of Linear Equations.
#
# A System of Linear Equations can be solved using the solve() function of linalg module of the library NumPy.

# %%
import numpy as np
matrix_1 = np.array([[1, 3, -1],
                     [2, 5, 4],
                     [2, 3, -1]])
# Define the vector
matrix_2 = np.array([4,19,7])

x= np.linalg.solve(matrix_1, matrix_2)
print("The value of x1 is: ",x[0])
print("The value of x2 is: ",x[1])
print("The value of x3 is: ",x[2])
# Out:
# The value of x1 is:  3.0
# The value of x2 is:  1.0
# The value of x3 is:  2.0

# %% [markdown]
# # **Algorithms to solve a system of linear equations**
#
# The two commonly used algorithms to solve a System of Linear Equations are:
#
# *   Gaussian Elimination
# *   Cramer’s Rule
#
#
# **1. Gaussian Elimination**
#
#
# Gaussian Elimination is an algorithm that helps in solving a System of Linear Equations through the following elementary row operations on Augmented matrix:
#
# 1. Swapping rows
# 2. Multiplying a row by a non-zero scalar
# 3. Adding a multiple of one row to another row
#
#
#
# 1. Create an augumented matrix
# 2. Apply below transformations:
#
#     R2 = R2 -2R1
#     R3 = R3 -2R1
#
# 3. On resultant matrix apply transformation and you will get and Upper Triangular matrix.
#
#     R3 = R3 -3R2
#
# 4. Now you can create a System of Equations from the reduced Augmented matrix and solve it.

# %% [markdown]
# **2. Gauss Jordan**
#
# Gauss Jordan is an extension of the Gaussian Elimination method to solve a System of Linear Equations. In this method, the elementary row operations on the resultant Upper Triangular matrix from Gaussian Elimination are continued to obtain a Diagonal matrix.
#
# Gauss Jordan technique can be used to find the inverse of a square matrix.

# %% [markdown]
# **3. Cramer’s Rule**
#
# Cramer’s Rule is a method to solve a System of Linear Equations. Unlike Gaussian Elimination, this rule helps in finding solutions to a subset of variables rather than solving the entire System of Linear Equations. This is helpful when linear equations contain large number of variables.

# %% [markdown]
# **Solving a System of Linear Equations when the number of variables and the number of equations is not equal**
#
#  Consider a System of Linear Equations Ax=b, where A is of dimension (m, n) and m ≠ n, then the system is called
#
#  1. Under - Determined System, when m < n
#  2. Over - Determined System, when m > n
#
#  Given Ax=b, if A is invertible (inverse exists) then the solution of the System of Linear Equations is,
#
#       x = A^(-1)b
#
# To find the inverse of A, when A is non-square, the generalized inverse technique needs to be used.
#
#       x = A^(-G)b
#
# Where, A^(-G) represents the generalized inverse of A (also known as the pseudo inverse).
#
# In NumPy, the pinv() from linalg module is used to find the generalized inverse of a matrix.

# %% [markdown]
# # **Excercise 1.2**
#
# Q1. Find the solution of the following System of Linear Equations using Cramer’s Rule.
#
#     2x + 3y + 2z = 1
#     x + 3z = 2
#     2x + 2y + 3z = 3

# %%
import numpy as np

A = np.array([[2, 3, 2],
              [1, 0, 3],
              [2, 2, 3]])

print("Matrix A : \n", A)
print("Shape of matrix A: ", A.shape)

B = np.array([[1], [2], [3]])
print("Matrix B : \n", B)
print("Shape of matrix B: ", B.shape)

DA = np.linalg.det(A)
print("Det of A: ", np.round(DA))

A1 =np.array([[1, 3, 2],
              [2, 0, 3],
              [3, 2, 3]])
print("Matrix A1 : \n", A1)
DA1 = np.linalg.det(A1)
print("Det of A1: ",np.round(DA1))

A2 =np.array([[2, 1, 2],
              [1, 2, 3],
              [2, 3, 3]])
print("Matrix A2 : \n", A2)
DA2 = np.linalg.det(A2)
print("Det of A2: ",np.round(DA2))

A3 =np.array([[2, 3, 1],
              [1, 0, 2],
              [2, 2, 3]])
print("Matrix A3 : \n", A3)
DA3 = np.linalg.det(A3)
print("Det of A3: ",np.round(DA3))

print("X1: ", np.round(DA1/DA))
print("X2: ", np.round(DA2/DA))
print("X3: ", np.round(DA3/DA))
# Out:
# Matrix A :
#  [[2 3 2]
#  [1 0 3]
#  [2 2 3]]
# Shape of matrix A:  (3, 3)
# Matrix B :
#  [[1]
#  [2]
#  [3]]
# Shape of matrix B:  (3, 1)
# Det of A:  1.0
# Matrix A1 :
#  [[1 3 2]
#  [2 0 3]
#  [3 2 3]]
# Det of A1:  11.0
# Matrix A2 :
#  [[2 1 2]
#  [1 2 3]
#  [2 3 3]]
# Det of A2:  -5.0
# Matrix A3 :
#  [[2 3 1]
#  [1 0 2]
#  [2 2 3]]
# Det of A3:  -3.0
# X1:  11.0
# X2:  -5.0
# X3:  -3.0

# %%
import numpy as np

A = np.array([[2, 3, 2],
              [1, 0, 3],
              [2, 2, 3]])

print("Matrix A : \n", A)
print("Shape of matrix A: ", A.shape)

B = np.array([1, 2, 3])
print("Matrix B : \n", B)
print("Shape of matrix B: ", B.shape)

x= np.linalg.solve(A, B)
print("The value of x1 is: ",x[0])
print("The value of x2 is: ",x[1])
print("The value of x3 is: ",x[2])
# Out:
# Matrix A :
#  [[2 3 2]
#  [1 0 3]
#  [2 2 3]]
# Shape of matrix A:  (3, 3)
# Matrix B :
#  [1 2 3]
# Shape of matrix B:  (3,)
# The value of x1 is:  11.000000000000007
# The value of x2 is:  -5.0000000000000036
# The value of x3 is:  -3.0000000000000027

# %% [markdown]
# Q2. Find the solution of the following System of Equations using Gaussian Elimination and Gauss Jordan method.
#
#     12x1 + x2 = 18
#     7x1 - 8x2 = 32
